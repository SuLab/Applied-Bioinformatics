# %% [markdown]
# A4.aa

# %%
# Q1: elements 
vector <- (1:100) # vector
# print(vector) 

list_data <- list("Red", "Green", c(21,32,11), TRUE, 51.23, 119.1)
print(list_data)
# Out:
# [[1]]
# [1] "Red"
#
# [[2]]
# [1] "Green"
#
# [[3]]
# [1] 21 32 11
#
# [[4]]
# [1] TRUE
#
# [[5]]
# [1] 51.23
#
# [[6]]
# [1] 119.1

# %%
# Q2: class() vs typeof()

# class(vector)
# typeof(vector)

# class(list_data)
# typeof(list_data)

# %%
# Q3: Guidance

# ?class() #what function does
# ?typeof()

# help(class(vector)) # whats happening

# example(list)
# integer
# list

# %% [markdown]
# A4.ab

# %%
# What's happening in this code cell?
nav.d14 <- read.csv("./data/NAV-D14_DEseq2.csv")
# nav.d14

# str(nav.d14)
# summary(nav.d14)

# %%
# Using lapply()

test <- lapply(nav.d14$baseMean, sum)

# ?
# apply()
# sapply() - vectors
# lapply() - lists 

# dplyr package
# https://dplyr.tidyverse.org/

# %% [markdown]
# A4.ba

# %%
# games.csv

# How to read file?
chess_games <- read.csv("./data/games.csv")

# How to view file?
# chess_games

# File contents?
## str(chess_games)
## summary(chess_games)

# Size of the dataframe?
# dim(chess_games)

# File label (label refresh)

# Question we want to ask about the data?  
## True and False, in blue
### head(chess_games)
chess_games_rated <- table(chess_games$rated)
# head(chess_games)
# chess_games_rated

# barplot(chess_games_rated)
# barplot(chess_games_rated, col=c("red","blue"))

# head(chess_games)
# chess_games_rated

# barplot(chess_games$rated)
barplot(chess_games_rated) #fxn 1
barplot(chess_games_rated, col=c("blue","red")) # fxn 2

# fxn 3
fxn3 <- i
    fxn1
    fxn2
return(print("a" ouptut-of-fxn1), print("b", output-of-fxn2))

fxn3()
# Out:
# plot without title
# Error in eval(expr, envir, enclos): object 'fxn' not found
# Traceback:
# plot without title

# %%
# package version

packageVersion("ggplot2") # v3.3.2
# Out:
# [1] ‘3.3.2’

# %% [markdown]
# A4.bb

# %%
# pseudocode function for having both bar plots out at the same time

# barplot(chess_games_rated, col=c("blue","red"))

fxn_name <-

# %%
# games.csv

# How to read file?
# games <- read.csv("./data/games.csv")


# How to view file?
# games

# File contents?
# summary(games)
## Size of the dataframe?
# dim(games)

# File label (label refresh)
# str(games)

# Question we want to ask about the data?  
## True and False, in blue
### rated <- table(games$rated)
#### barplot(rated, col="blue")
# Out:
# plot without title

# %%
# package version

# packageVersion("ggplot2") # note syntax

# %% [markdown]
# A4.bb

# %%
# pseudocode function for making a figure

# assign <- transformfxn(df$column-interest)
