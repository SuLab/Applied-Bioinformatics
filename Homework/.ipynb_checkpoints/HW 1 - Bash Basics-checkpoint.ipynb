# %% [markdown]
# # Homework 1: Jupyter and Bash Basics
# Curated by Sabah Ul-Hasan, Huitian Dao, Karthik Gangavarapu, and Andrew Su
#
# Homeworks are due every Tuesday at 8 AM PST.<br>
# Download your homework as a pdf for TAs to provide feedback: HW#_LastName.PDF<br>
# Make sure to save your work constantly so the efforts don't get lost!
#
# In this assignment, you will <br>
# A1.aa Practice basic bash operations in terminal and functionality of Jupyter notebook (R kernel)<br>
# A1.ab Execute basic operations of bash commands in Jupyter notebook <br>
# A1.ba Utilize bash for more sophisicated tasks, such as pipes <br>
# A1.bb Solidfy your understanding of bash by practice

# %% [markdown]
# ### A1.aa: Github and Jupyter notebook [20-30 min] Individual
#
# #### aa.i Confirmation of Github account and download of data in Bioinformatics course repo<br>
# Go to https://github.com/SuLab/Applied-Bioinformatics/tree/Fall-2020 and download as a zip file.<br>
# Instead of looking via your Finder, use the command line to identify where this zip file has been downloaded and unzip. <br>
# Then, use command line to find where the 'data' folder is located within 'Homework.'<br>
# 1. Did you find this folder? Y/N <br>
# [Type out any obstacles you encounter here] <br>
# ##### Answer: Students should use a combination of ls, pwd, and cd to reach their Downloads folder.<br>Once there, ```unzip [filename]```<br>
#
# #### aa.ii Confirmation of basic Jupyter notebook operations <br>
# Use ```jupyter notebook``` to open HW 1 in your browser <br>
# 2. Do you see the same screen as shared by the instructors? Y/N <br>
# Create a new cell below this one by clicking on this cell and the selecting "Insert"->"Insert Cell Below".<br>
# 3. Are you able to run the cell with an output after typing ```2+3```? Y/N<br>
# 4. Notice the different settings (ie Markdown). What do they mean?<br>
# 5. Why did we need to install the R kernel, whereas Python 3 was automatically included?<br>
# 6. What additional observations do you have of Jupyter notebook, and how it functions? Play around with it and take notes of your observations. <br>
# [Type out any obstacles you encounter here] <br>
# ##### Answer: <br>

# %%
# 3
2+3
# Out:
# [1] 5

# %% [markdown]
# ### A1.ab: Execute basic bash commands in R (using Jupyter) [20-30 min] TPS
# #### ab.i Confirmation of basic bash operations <br>
# Usually, you would want to use command line in your terminal to run an R script for a given job/task. We're going to do the opposite (run command line using R code). To do this, you will utilize the ```system()``` function.<br>
# 1. For example, what happens when you run the following script into a new cell?<br>
# ```
# system('pwd', intern=TRUE)
# ```
# 2. Describe in further detail what the ```system()``` function means. Additionally, when and why do need to include ```intern=TRUE``` within this function?<br>
# ##### Answer: <br>
#
# #### ab.ii Continuation of basic bash operations <br>
# Use the basic command lines covered in lecture to walk through the following exercises <br>
# 2. Find and output the 'artists.txt' file
# 3. Find and output the artist Francesco Albani - what year was he born?
# 4. Count the number of artists in the file that are *not* French.
# 5. Script your own task that includes 1-2 basic commands we haven't yet tried.
# ##### Answers: below
#
# #### ab.iii Developing these skills on your own time <br>
# Now that we've worked through these in pairs, try the following exercises on your own. Have them complete pior to next class. <br>
# 6. How would you view the first 10 lines of 'artists.txt'?
# 7. Make a copy of 'artists.txt' and rename it as 'artists_new.txt'. Move the new copy to a new folder titled 'new_folder' in the 'data' folder, but outside of the 'art' folder.
# 8. Now, create your own script that gives us some information about about the artists.txt file that we didn't know about before or haven't yet tried. Ask a question about the data, then answer it with your script! Utilize the ```sort``` command as part of your script.
# 9. Reflections: On an integer scale of 1-5, 1 being very easy and 5 being the most difficult, where would you rank today's exercises? Be honest! It's okay if you put a 5, and will help us better understand how to make sure your needs are being met.

# %%
# 2
system('ls data/art', intern=TRUE)
# Out:
# [1] "artists.txt"

# %%
# 3
system('cd data/art 
grep ALBANI artists.txt', intern=TRUE)
# Out:
# [1] "ALBANI, Francesco\t(1578-1660)\tBaroque\tItalian painter (Bologna)"

# %%
# 4
system('cd data/art 
grep -c -v French artists.txt', intern=TRUE)
# Out:
# [1] "138"

# %%
# 5

# %%
# 6
system('cd data/art
head artists.txt', intern=TRUE)
# Out:
#  [1] "KILIAN, Wolfgang\t(1581-1662)\tBaroque\tGerman graphic artist (Augsburg)"
#  [2] "KINSOEN, François-Joseph\t(1771-1839)\tRomanticism\tFlemish painter"
#  [3] "KISS, August Karl Edouard\t(1802-1865)\tRomanticism\tGerman sculptor"
#  [4] "KISS, Bálint\t(1802-1868)\tRomanticism\tHungarian painter (Pest)"
#  [5] "KLEINER, Salomon\t(1703-1761)\tBaroque\tGerman graphic artist"
#  [6] "KLENZE, Leo von\t(1784-1864)\tRomanticism\tGerman architect"
#  [7] "KLESECKER, Justus (see GLESKER, Justus)\t(c. 1615-1678)\tBaroque\tGerman sculptor (Franconia)"
#  [8] "KLINGER, Max\t(1857-1920)\tRealism\tGerman painter"
#  [9] "KLOCKER, Hans\t(active 1478-1500l)\tNorthern Renaissance\tAustrian sculptor (South Tyrol)"
# [10] "KLODT, Mikhail Konstantinovich\t(c. 1832-1902)\tRealism\tRussian painter (St. Petersburg)"

# %%
# 7
system('cd data/
mkdir new_folder
cp art/artists.txt new_folder/artists_new.txt', intern=TRUE)
# Out:
# character(0)

# %%
# 8

# %%
# 9

# %% [markdown]
# ### A1.ba: Wildcards, redirections, and pipes [20-30 min] Group of 3
# #### ba.i Glob <br>
# 1. What is glob, and why use it compared to basic command line functions?
# 2. Utliize glob to create a command that lists all the .txt files in the 'tmp' directory, located in 'data'. What could be another way to 'glob'? Include this answer as a few sentences.
# ##### Answer: <br>
#
# #### ba.i Redirection and pipes <br>
# In your, work on these individually and then compare your scripts.
# 3. What does it mean to redirect, and why would you utilize a pipe over a basic command line?
# 4. Building off of glob, use a pipe to count the number of .txt files in data/tmp
# 5. Now, redirect the counted number as a saved 'file_number.txt' file to the 'new_folder' directory. What happens to the file if you repeat the same task, but exclude the pipe (name this 'file_list.txt' so you can compare)?
# 6. How do your scripts compare or differ, either in input (command) or output?

# %%
# 2
system('ls data/tmp/*.txt', intern=TRUE)
# Out:
#   [1] "data/tmp/file1.txt"   "data/tmp/file10.txt"  "data/tmp/file100.txt"
#   [4] "data/tmp/file101.txt" "data/tmp/file102.txt" "data/tmp/file103.txt"
#   [7] "data/tmp/file104.txt" "data/tmp/file105.txt" "data/tmp/file106.txt"
#  [10] "data/tmp/file107.txt" "data/tmp/file108.txt" "data/tmp/file109.txt"
#  [13] "data/tmp/file11.txt"  "data/tmp/file110.txt" "data/tmp/file111.txt"
#  [16] "data/tmp/file114.txt" "data/tmp/file115.txt" "data/tmp/file116.txt"
#  [19] "data/tmp/file117.txt" "data/tmp/file118.txt" "data/tmp/file119.txt"
#  [22] "data/tmp/file12.txt"  "data/tmp/file120.txt" "data/tmp/file121.txt"
#  [25] "data/tmp/file122.txt" "data/tmp/file123.txt" "data/tmp/file124.txt"
#  [28] "data/tmp/file125.txt" "data/tmp/file126.txt" "data/tmp/file127.txt"
#  [31] "data/tmp/file128.txt" "data/tmp/file129.txt" "data/tmp/file13.txt"
#  [34] "data/tmp/file130.txt" "data/tmp/file131.txt" "data/tmp/file132.txt"
#  [37] "data/tmp/file133.txt" "data/tmp/file134.txt" "data/tmp/file135.txt"
#  [40] "data/tmp/file136.txt" "data/tmp/file138.txt" "data/tmp/file139.txt"
#  [43] "data/tmp/file14.txt"  "data/tmp/file140.txt" "data/tmp/file141.txt"
#  [46] "data/tmp/file142.txt" "data/tmp/file143.txt" "data/tmp/file144.txt"
#  [49] "data/tmp/file145.txt" "data/tmp/file146.txt" "data/tmp/file147.txt"
#  [52] "data/tmp/file148.txt" "data/tmp/file149.txt" "data/tmp/file15.txt"
#  [55] "data/tmp/file150.txt" "data/tmp/file151.txt" "data/tmp/file152.txt"
#  [58] "data/tmp/file153.txt" "data/tmp/file154.txt" "data/tmp/file155.txt"
#  [61] "data/tmp/file156.txt" "data/tmp/file157.txt" "data/tmp/file158.txt"
#  [64] "data/tmp/file159.txt" "data/tmp/file16.txt"  "data/tmp/file160.txt"
#  [67] "data/tmp/file161.txt" "data/tmp/file162.txt" "data/tmp/file163.txt"
#  [70] "data/tmp/file164.txt" "data/tmp/file165.txt" "data/tmp/file166.txt"
#  [73] "data/tmp/file167.txt" "data/tmp/file168.txt" "data/tmp/file169.txt"
#  [76] "data/tmp/file17.txt"  "data/tmp/file170.txt" "data/tmp/file171.txt"
#  [79] "data/tmp/file172.txt" "data/tmp/file173.txt" "data/tmp/file174.txt"
#  [82] "data/tmp/file175.txt" "data/tmp/file176.txt" "data/tmp/file177.txt"
#  [85] "data/tmp/file178.txt" "data/tmp/file179.txt" "data/tmp/file18.txt"
#  [88] "data/tmp/file180.txt" "data/tmp/file181.txt" "data/tmp/file182.txt"
#  [91] "data/tmp/file183.txt" "data/tmp/file184.txt" "data/tmp/file185.txt"
#  [94] "data/tmp/file186.txt" "data/tmp/file187.txt" "data/tmp/file188.txt"
#  [97] "data/tmp/file189.txt" "data/tmp/file19.txt"  "data/tmp/file190.txt"
# [100] "data/tmp/file191.txt" "data/tmp/file192.txt" "data/tmp/file193.txt"
# [103] "data/tmp/file194.txt" "data/tmp/file195.txt" "data/tmp/file196.txt"
# [106] "data/tmp/file197.txt" "data/tmp/file198.txt" "data/tmp/file199.txt"
# [109] "data/tmp/file2.txt"   "data/tmp/file200.txt" "data/tmp/file21.txt"
# [112] "data/tmp/file22.txt"  "data/tmp/file23.txt"  "data/tmp/file24.txt"
# [115] "data/tmp/file25.txt"  "data/tmp/file26.txt"  "data/tmp/file27.txt"
# [118] "data/tmp/file28.txt"  "data/tmp/file29.txt"  "data/tmp/file3.txt"
# [121] "data/tmp/file30.txt"  "data/tmp/file31.txt"  "data/tmp/file32.txt"
# [124] "data/tmp/file33.txt"  "data/tmp/file34.txt"  "data/tmp/file35.txt"
# [127] "data/tmp/file36.txt"  "data/tmp/file38.txt"  "data/tmp/file39.txt"
# [130] "data/tmp/file4.txt"   "data/tmp/file40.txt"  "data/tmp/file41.txt"
# [133] "data/tmp/file42.txt"  "data/tmp/file44.txt"  "data/tmp/file45.txt"
# [136] "data/tmp/file46.txt"  "data/tmp/file47.txt"  "data/tmp/file48.txt"
# [139] "data/tmp/file49.txt"  "data/tmp/file5.txt"   "data/tmp/file50.txt"
# [142] "data/tmp/file51.txt"  "data/tmp/file52.txt"  "data/tmp/file53.txt"
# [145] "data/tmp/file54.txt"  "data/tmp/file55.txt"  "data/tmp/file56.txt"
# [148] "data/tmp/file57.txt"  "data/tmp/file58.txt"  "data/tmp/file59.txt"
# [151] "data/tmp/file6.txt"   "data/tmp/file60.txt"  "data/tmp/file61.txt"
# [154] "data/tmp/file62.txt"  "data/tmp/file64.txt"  "data/tmp/file65.txt"
# [157] "data/tmp/file66.txt"  "data/tmp/file67.txt"  "data/tmp/file68.txt"
# [160] "data/tmp/file69.txt"  "data/tmp/file7.txt"   "data/tmp/file70.txt"
# [163] "data/tmp/file71.txt"  "data/tmp/file72.txt"  "data/tmp/file73.txt"
# [166] "data/tmp/file74.txt"  "data/tmp/file75.txt"  "data/tmp/file76.txt"
# [169] "data/tmp/file77.txt"  "data/tmp/file78.txt"  "data/tmp/file79.txt"
# [172] "data/tmp/file8.txt"   "data/tmp/file80.txt"  "data/tmp/file81.txt"
# [175] "data/tmp/file82.txt"  "data/tmp/file84.txt"  "data/tmp/file85.txt"
# [178] "data/tmp/file86.txt"  "data/tmp/file87.txt"  "data/tmp/file88.txt"
# [181] "data/tmp/file89.txt"  "data/tmp/file9.txt"   "data/tmp/file90.txt"
# [184] "data/tmp/file91.txt"  "data/tmp/file92.txt"  "data/tmp/file93.txt"
# [187] "data/tmp/file94.txt"  "data/tmp/file96.txt"  "data/tmp/file97.txt"
# [190] "data/tmp/file98.txt"  "data/tmp/file99.txt"

# %%
# 4
system('ls data/tmp/*.txt | wc -l', intern=TRUE)
# Out:
# [1] "     191"

# %%
# 5
system('ls data/tmp/*.txt | wc -l > data/new_folder/file_number.txt
ls data/tmp/*.txt > data/new_folder/file_list.txt', intern=TRUE)
# Out:
# character(0)

# %% [markdown]
# ### A1.bb: Affirming what you learned in Week 1 [20-30 min, assignment] Individual
# 1. What is the distinction between an absolute vs relative file path? Script an example of these two comparison along with a brief written answer.
# 2. What are 3 ways you can extend the ```ls``` command to give you more information, and what do they give?
# 3. Create a file named 'test.txt', move it into the 'new_folder', then delete the file.
# 4. Create a sorted file artists (alphabetical order) from 'artists.txt' labeled as 'artists_sorted.txt' and place it in the 'new_folder'. Then identify the number of unique artists in that file.
# 5. Use nano in your terminal (not jupyter notebook) to create a bash script titled 'print_names.sh' that echos any name entered in a list of 4 names (3 of the names are fixed, the 4th is not). Move the script to 'new_folder', then run it. Take a screenshot of the input to run the script and output. Briefly explain why you have to do this on terminal, and can't run this on your Jupyter notebook?
# 6. Use nano to create your own script that uses 2 commands we've used and 1 command we haven't yet used (3 total, but you can include more if you'd like) that answers another question you have about the contents of the 'artists.txt' file. Label this script as 'artist_text.sh' and place it in 'new_folder'. Describe what it does, and how.
# 7. Reflections: On an integer scale of 1-5, 1 being very easy and 5 being the most difficult, where would you rank the A1.bb assignment and why? Include some notes about what you gained from this past week that you didn't know before as well as notes of things you already knew.

# %%
# 1
system('cd data/tmp/')
system('pwd', intern=TRUE)
system('cd .')
system('pwd', intern=TRUE)
# Out:
# [1] "/Users/sulhasan/Downloads/Applied-Bioinformatics/Homework"
# [1] "/Users/sulhasan/Downloads/Applied-Bioinformatics/Homework"

# %%
# 2
system('ls data/tmp/', intern=TRUE)
system('ls -F data/tmp/', intern=TRUE)
system('ls -a data/tmp/', intern=TRUE)
system('man ls', intern=TRUE)
# Out:
#   [1] "file1.txt"   "file10.txt"  "file100.txt" "file101.txt" "file102.txt"
#   [6] "file103.txt" "file104.txt" "file105.txt" "file106.txt" "file107.txt"
#  [11] "file108.txt" "file109.txt" "file11.txt"  "file110.txt" "file111.txt"
#  [16] "file114.txt" "file115.txt" "file116.txt" "file117.txt" "file118.txt"
#  [21] "file119.txt" "file12.txt"  "file120.txt" "file121.txt" "file122.txt"
#  [26] "file123.txt" "file124.txt" "file125.txt" "file126.txt" "file127.txt"
#  [31] "file128.txt" "file129.txt" "file13.txt"  "file130.txt" "file131.txt"
#  [36] "file132.txt" "file133.txt" "file134.txt" "file135.txt" "file136.txt"
#  [41] "file138.txt" "file139.txt" "file14.txt"  "file140.txt" "file141.txt"
#  [46] "file142.txt" "file143.txt" "file144.txt" "file145.txt" "file146.txt"
#  [51] "file147.txt" "file148.txt" "file149.txt" "file15.txt"  "file150.txt"
#  [56] "file151.txt" "file152.txt" "file153.txt" "file154.txt" "file155.txt"
#  [61] "file156.txt" "file157.txt" "file158.txt" "file159.txt" "file16.txt"
#  [66] "file160.txt" "file161.txt" "file162.txt" "file163.txt" "file164.txt"
#  [71] "file165.txt" "file166.txt" "file167.txt" "file168.txt" "file169.txt"
#  [76] "file17.txt"  "file170.txt" "file171.txt" "file172.txt" "file173.txt"
#  [81] "file174.txt" "file175.txt" "file176.txt" "file177.txt" "file178.txt"
#  [86] "file179.txt" "file18.txt"  "file180.txt" "file181.txt" "file182.txt"
#  [91] "file183.txt" "file184.txt" "file185.txt" "file186.txt" "file187.txt"
#  [96] "file188.txt" "file189.txt" "file19.txt"  "file190.txt" "file191.txt"
# [101] "file192.csv" "file192.txt" "file193.txt" "file194.txt" "file195.txt"
# [106] "file196.txt" "file197.txt" "file198.txt" "file199.txt" "file2.txt"
# [111] "file200.txt" "file21.txt"  "file22.txt"  "file23.txt"  "file24.txt"
# [116] "file25.txt"  "file26.txt"  "file27.txt"  "file28.txt"  "file29.txt"
# [121] "file3.txt"   "file30.txt"  "file31.txt"  "file32.txt"  "file33.csv"
# [126] "file33.txt"  "file34.txt"  "file35.txt"  "file36.txt"  "file38.txt"
# [131] "file39.txt"  "file4.txt"   "file40.txt"  "file41.txt"  "file42.txt"
# [136] "file44.txt"  "file45.txt"  "file46.txt"  "file47.txt"  "file48.txt"
# [141] "file49.txt"  "file5.txt"   "file50.txt"  "file51.txt"  "file52.txt"
# [146] "file53.txt"  "file54.txt"  "file55.txt"  "file56.txt"  "file57.txt"
# [151] "file58.txt"  "file59.txt"  "file6.txt"   "file60.txt"  "file61.txt"
# [156] "file62.txt"  "file64.txt"  "file65.txt"  "file66.txt"  "file67.txt"
# [161] "file68.txt"  "file69.txt"  "file7.txt"   "file70.txt"  "file71.txt"
# [166] "file72.txt"  "file73.txt"  "file74.txt"  "file75.txt"  "file76.txt"
# [171] "file77.txt"  "file78.txt"  "file79.txt"  "file8.txt"   "file80.txt"
# [176] "file81.txt"  "file82.txt"  "file84.txt"  "file85.txt"  "file86.txt"
# [181] "file87.txt"  "file88.txt"  "file89.txt"  "file9.txt"   "file90.txt"
# [186] "file91.txt"  "file92.txt"  "file93.txt"  "file94.txt"  "file96.csv"
# [191] "file96.txt"  "file97.txt"  "file98.txt"  "file99.txt"
#   [1] "file1.txt"   "file10.txt"  "file100.txt" "file101.txt" "file102.txt"
#   [6] "file103.txt" "file104.txt" "file105.txt" "file106.txt" "file107.txt"
#  [11] "file108.txt" "file109.txt" "file11.txt"  "file110.txt" "file111.txt"
#  [16] "file114.txt" "file115.txt" "file116.txt" "file117.txt" "file118.txt"
#  [21] "file119.txt" "file12.txt"  "file120.txt" "file121.txt" "file122.txt"
#  [26] "file123.txt" "file124.txt" "file125.txt" "file126.txt" "file127.txt"
#  [31] "file128.txt" "file129.txt" "file13.txt"  "file130.txt" "file131.txt"
#  [36] "file132.txt" "file133.txt" "file134.txt" "file135.txt" "file136.txt"
#  [41] "file138.txt" "file139.txt" "file14.txt"  "file140.txt" "file141.txt"
#  [46] "file142.txt" "file143.txt" "file144.txt" "file145.txt" "file146.txt"
#  [51] "file147.txt" "file148.txt" "file149.txt" "file15.txt"  "file150.txt"
#  [56] "file151.txt" "file152.txt" "file153.txt" "file154.txt" "file155.txt"
#  [61] "file156.txt" "file157.txt" "file158.txt" "file159.txt" "file16.txt"
#  [66] "file160.txt" "file161.txt" "file162.txt" "file163.txt" "file164.txt"
#  [71] "file165.txt" "file166.txt" "file167.txt" "file168.txt" "file169.txt"
#  [76] "file17.txt"  "file170.txt" "file171.txt" "file172.txt" "file173.txt"
#  [81] "file174.txt" "file175.txt" "file176.txt" "file177.txt" "file178.txt"
#  [86] "file179.txt" "file18.txt"  "file180.txt" "file181.txt" "file182.txt"
#  [91] "file183.txt" "file184.txt" "file185.txt" "file186.txt" "file187.txt"
#  [96] "file188.txt" "file189.txt" "file19.txt"  "file190.txt" "file191.txt"
# [101] "file192.csv" "file192.txt" "file193.txt" "file194.txt" "file195.txt"
# [106] "file196.txt" "file197.txt" "file198.txt" "file199.txt" "file2.txt"
# [111] "file200.txt" "file21.txt"  "file22.txt"  "file23.txt"  "file24.txt"
# [116] "file25.txt"  "file26.txt"  "file27.txt"  "file28.txt"  "file29.txt"
# [121] "file3.txt"   "file30.txt"  "file31.txt"  "file32.txt"  "file33.csv"
# [126] "file33.txt"  "file34.txt"  "file35.txt"  "file36.txt"  "file38.txt"
# [131] "file39.txt"  "file4.txt"   "file40.txt"  "file41.txt"  "file42.txt"
# [136] "file44.txt"  "file45.txt"  "file46.txt"  "file47.txt"  "file48.txt"
# [141] "file49.txt"  "file5.txt"   "file50.txt"  "file51.txt"  "file52.txt"
# [146] "file53.txt"  "file54.txt"  "file55.txt"  "file56.txt"  "file57.txt"
# [151] "file58.txt"  "file59.txt"  "file6.txt"   "file60.txt"  "file61.txt"
# [156] "file62.txt"  "file64.txt"  "file65.txt"  "file66.txt"  "file67.txt"
# [161] "file68.txt"  "file69.txt"  "file7.txt"   "file70.txt"  "file71.txt"
# [166] "file72.txt"  "file73.txt"  "file74.txt"  "file75.txt"  "file76.txt"
# [171] "file77.txt"  "file78.txt"  "file79.txt"  "file8.txt"   "file80.txt"
# [176] "file81.txt"  "file82.txt"  "file84.txt"  "file85.txt"  "file86.txt"
# [181] "file87.txt"  "file88.txt"  "file89.txt"  "file9.txt"   "file90.txt"
# [186] "file91.txt"  "file92.txt"  "file93.txt"  "file94.txt"  "file96.csv"
# [191] "file96.txt"  "file97.txt"  "file98.txt"  "file99.txt"
#   [1] "."           ".."          "file1.txt"   "file10.txt"  "file100.txt"
#   [6] "file101.txt" "file102.txt" "file103.txt" "file104.txt" "file105.txt"
#  [11] "file106.txt" "file107.txt" "file108.txt" "file109.txt" "file11.txt"
#  [16] "file110.txt" "file111.txt" "file114.txt" "file115.txt" "file116.txt"
#  [21] "file117.txt" "file118.txt" "file119.txt" "file12.txt"  "file120.txt"
#  [26] "file121.txt" "file122.txt" "file123.txt" "file124.txt" "file125.txt"
#  [31] "file126.txt" "file127.txt" "file128.txt" "file129.txt" "file13.txt"
#  [36] "file130.txt" "file131.txt" "file132.txt" "file133.txt" "file134.txt"
#  [41] "file135.txt" "file136.txt" "file138.txt" "file139.txt" "file14.txt"
#  [46] "file140.txt" "file141.txt" "file142.txt" "file143.txt" "file144.txt"
#  [51] "file145.txt" "file146.txt" "file147.txt" "file148.txt" "file149.txt"
#  [56] "file15.txt"  "file150.txt" "file151.txt" "file152.txt" "file153.txt"
#  [61] "file154.txt" "file155.txt" "file156.txt" "file157.txt" "file158.txt"
#  [66] "file159.txt" "file16.txt"  "file160.txt" "file161.txt" "file162.txt"
#  [71] "file163.txt" "file164.txt" "file165.txt" "file166.txt" "file167.txt"
#  [76] "file168.txt" "file169.txt" "file17.txt"  "file170.txt" "file171.txt"
#  [81] "file172.txt" "file173.txt" "file174.txt" "file175.txt" "file176.txt"
#  [86] "file177.txt" "file178.txt" "file179.txt" "file18.txt"  "file180.txt"
#  [91] "file181.txt" "file182.txt" "file183.txt" "file184.txt" "file185.txt"
#  [96] "file186.txt" "file187.txt" "file188.txt" "file189.txt" "file19.txt"
# [101] "file190.txt" "file191.txt" "file192.csv" "file192.txt" "file193.txt"
# [106] "file194.txt" "file195.txt" "file196.txt" "file197.txt" "file198.txt"
# [111] "file199.txt" "file2.txt"   "file200.txt" "file21.txt"  "file22.txt"
# [116] "file23.txt"  "file24.txt"  "file25.txt"  "file26.txt"  "file27.txt"
# [121] "file28.txt"  "file29.txt"  "file3.txt"   "file30.txt"  "file31.txt"
# [126] "file32.txt"  "file33.csv"  "file33.txt"  "file34.txt"  "file35.txt"
# [131] "file36.txt"  "file38.txt"  "file39.txt"  "file4.txt"   "file40.txt"
# [136] "file41.txt"  "file42.txt"  "file44.txt"  "file45.txt"  "file46.txt"
# [141] "file47.txt"  "file48.txt"  "file49.txt"  "file5.txt"   "file50.txt"
# [146] "file51.txt"  "file52.txt"  "file53.txt"  "file54.txt"  "file55.txt"
# [151] "file56.txt"  "file57.txt"  "file58.txt"  "file59.txt"  "file6.txt"
# [156] "file60.txt"  "file61.txt"  "file62.txt"  "file64.txt"  "file65.txt"
# [161] "file66.txt"  "file67.txt"  "file68.txt"  "file69.txt"  "file7.txt"
# [166] "file70.txt"  "file71.txt"  "file72.txt"  "file73.txt"  "file74.txt"
# [171] "file75.txt"  "file76.txt"  "file77.txt"  "file78.txt"  "file79.txt"
# [176] "file8.txt"   "file80.txt"  "file81.txt"  "file82.txt"  "file84.txt"
# [181] "file85.txt"  "file86.txt"  "file87.txt"  "file88.txt"  "file89.txt"
# [186] "file9.txt"   "file90.txt"  "file91.txt"  "file92.txt"  "file93.txt"
# [191] "file94.txt"  "file96.csv"  "file96.txt"  "file97.txt"  "file98.txt"
# [196] "file99.txt"
#   [1] ""
#   [2] "LS(1)                     BSD General Commands Manual                    LS(1)"
#   [3] ""
#   [4] "N\bNA\bAM\bME\bE"
#   [5] "     l\bls\bs -- list directory contents"
#   [6] ""
#   [7] "S\bSY\bYN\bNO\bOP\bPS\bSI\bIS\bS"
#   [8] "     l\bls\bs [-\b-A\bAB\bBC\bCF\bFG\bGH\bHL\bLO\bOP\bPR\bRS\bST\bTU\bUW\bW@\b@a\bab\bbc\bcd\bde\bef\bfg\bgh\bhi\bik\bkl\blm\bmn\bno\bop\bpq\bqr\brs\bst\btu\buw\bwx\bx1\b1%\b%] [_\bf_\bi_\bl_\be _\b._\b._\b.]"
#   [9] ""
#  [10] "D\bDE\bES\bSC\bCR\bRI\bIP\bPT\bTI\bIO\bON\bN"
#  [11] "     For each operand that names a _\bf_\bi_\bl_\be of a type other than directory, l\bls\bs"
#  [12] "     displays its name as well as any requested, associated information.  For"
#  [13] "     each operand that names a _\bf_\bi_\bl_\be of type directory, l\bls\bs displays the names"
#  [14] "     of files contained within that directory, as well as any requested, asso-"
#  [15] "     ciated information."
#  [16] ""
#  [17] "     If no operands are given, the contents of the current directory are dis-"
#  [18] "     played.  If more than one operand is given, non-directory operands are"
#  [19] "     displayed first; directory and non-directory operands are sorted sepa-"
#  [20] "     rately and in lexicographical order."
#  [21] ""
#  [22] "     The following options are available:"
#  [23] ""
#  [24] "     -\b-@\b@      Display extended attribute keys and sizes in long (-\b-l\bl) output."
#  [25] ""
#  [26] "     -\b-1\b1      (The numeric digit ``one''.)  Force output to be one entry per"
#  [27] "             line.  This is the default when output is not to a terminal."
#  [28] ""
#  [29] "     -\b-A\bA      List all entries except for _\b. and _\b._\b..  Always set for the super-"
#  [30] "             user."
#  [31] ""
#  [32] "     -\b-a\ba      Include directory entries whose names begin with a dot (_\b.)."
#  [33] ""
#  [34] "     -\b-B\bB      Force printing of non-printable characters (as defined by"
#  [35] "             ctype(3) and current locale settings) in file names as \\_\bx_\bx_\bx,"
#  [36] "             where _\bx_\bx_\bx is the numeric value of the character in octal."
#  [37] ""
#  [38] "     -\b-b\bb      As -\b-B\bB, but use C escape codes whenever possible."
#  [39] ""
#  [40] "     -\b-C\bC      Force multi-column output; this is the default when output is to"
#  [41] "             a terminal."
#  [42] ""
#  [43] "     -\b-c\bc      Use time when file status was last changed for sorting (-\b-t\bt) or"
#  [44] "             long printing (-\b-l\bl)."
#  [45] ""
#  [46] "     -\b-d\bd      Directories are listed as plain files (not searched recursively)."
#  [47] ""
#  [48] "     -\b-e\be      Print the Access Control List (ACL) associated with the file, if"
#  [49] "             present, in long (-\b-l\bl) output."
#  [50] ""
#  [51] "     -\b-F\bF      Display a slash (`/') immediately after each pathname that is a"
#  [52] "             directory, an asterisk (`*') after each that is executable, an at"
#  [53] "             sign (`@') after each symbolic link, an equals sign (`=') after"
#  [54] "             each socket, a percent sign (`%') after each whiteout, and a ver-"
#  [55] "             tical bar (`|') after each that is a FIFO."
#  [56] ""
#  [57] "     -\b-f\bf      Output is not sorted.  This option turns on the -\b-a\ba option."
#  [58] ""
#  [59] "     -\b-G\bG      Enable colorized output.  This option is equivalent to defining"
#  [60] "             CLICOLOR in the environment.  (See below.)"
#  [61] ""
#  [62] "     -\b-g\bg      This option is only available for compatibility with POSIX; it is"
#  [63] "             used to display the group name in the long (-\b-l\bl) format output"
#  [64] "             (the owner name is suppressed)."
#  [65] ""
#  [66] "     -\b-H\bH      Symbolic links on the command line are followed.  This option is"
#  [67] "             assumed if none of the -\b-F\bF, -\b-d\bd, or -\b-l\bl options are specified."
#  [68] ""
#  [69] "     -\b-h\bh      When used with the -\b-l\bl option, use unit suffixes: Byte, Kilobyte,"
#  [70] "             Megabyte, Gigabyte, Terabyte and Petabyte in order to reduce the"
#  [71] "             number of digits to three or less using base 2 for sizes."
#  [72] ""
#  [73] "     -\b-i\bi      For each file, print the file's file serial number (inode num-"
#  [74] "             ber)."
#  [75] ""
#  [76] "     -\b-k\bk      If the -\b-s\bs option is specified, print the file size allocation in"
#  [77] "             kilobytes, not blocks.  This option overrides the environment"
#  [78] "             variable BLOCKSIZE."
#  [79] ""
#  [80] "     -\b-L\bL      Follow all symbolic links to final target and list the file or"
#  [81] "             directory the link references rather than the link itself.  This"
#  [82] "             option cancels the -\b-P\bP option."
#  [83] ""
#  [84] "     -\b-l\bl      (The lowercase letter ``ell''.)  List in long format.  (See"
#  [85] "             below.)  A total sum for all the file sizes is output on a line"
#  [86] "             before the long listing."
#  [87] ""
#  [88] "     -\b-m\bm      Stream output format; list files across the page, separated by"
#  [89] "             commas."
#  [90] ""
#  [91] "     -\b-n\bn      Display user and group IDs numerically, rather than converting to"
#  [92] "             a user or group name in a long (-\b-l\bl) output.  This option turns on"
#  [93] "             the -\b-l\bl option."
#  [94] ""
#  [95] "     -\b-O\bO      Include the file flags in a long (-\b-l\bl) output."
#  [96] ""
#  [97] "     -\b-o\bo      List in long format, but omit the group id."
#  [98] ""
#  [99] "     -\b-P\bP      If argument is a symbolic link, list the link itself rather than"
# [100] "             the object the link references.  This option cancels the -\b-H\bH and"
# [101] "             -\b-L\bL options."
# [102] ""
# [103] "     -\b-p\bp      Write a slash (`/') after each filename if that file is a direc-"
# [104] "             tory."
# [105] ""
# [106] "     -\b-q\bq      Force printing of non-graphic characters in file names as the"
# [107] "             character `?'; this is the default when output is to a terminal."
# [108] ""
# [109] "     -\b-R\bR      Recursively list subdirectories encountered."
# [110] ""
# [111] "     -\b-r\br      Reverse the order of the sort to get reverse lexicographical"
# [112] "             order or the oldest entries first (or largest files last, if com-"
# [113] "             bined with sort by size"
# [114] ""
# [115] "     -\b-S\bS      Sort files by size"
# [116] ""
# [117] "     -\b-s\bs      Display the number of file system blocks actually used by each"
# [118] "             file, in units of 512 bytes, where partial units are rounded up"
# [119] "             to the next integer value.  If the output is to a terminal, a"
# [120] "             total sum for all the file sizes is output on a line before the"
# [121] "             listing.  The environment variable BLOCKSIZE overrides the unit"
# [122] "             size of 512 bytes."
# [123] ""
# [124] "     -\b-T\bT      When used with the -\b-l\bl (lowercase letter ``ell'') option, display"
# [125] "             complete time information for the file, including month, day,"
# [126] "             hour, minute, second, and year."
# [127] ""
# [128] "     -\b-t\bt      Sort by time modified (most recently modified first) before sort-"
# [129] "             ing the operands by lexicographical order."
# [130] ""
# [131] "     -\b-u\bu      Use time of last access, instead of last modification of the file"
# [132] "             for sorting (-\b-t\bt) or long printing (-\b-l\bl)."
# [133] ""
# [134] "     -\b-U\bU      Use time of file creation, instead of last modification for sort-"
# [135] "             ing (-\b-t\bt) or long output (-\b-l\bl)."
# [136] ""
# [137] "     -\b-v\bv      Force unedited printing of non-graphic characters; this is the"
# [138] "             default when output is not to a terminal."
# [139] ""
# [140] "     -\b-W\bW      Display whiteouts when scanning directories.  (-\b-S\bS) flag)."
# [141] ""
# [142] "     -\b-w\bw      Force raw printing of non-printable characters.  This is the"
# [143] "             default when output is not to a terminal."
# [144] ""
# [145] "     -\b-x\bx      The same as -\b-C\bC, except that the multi-column output is produced"
# [146] "             with entries sorted across, rather than down, the columns."
# [147] ""
# [148] "     -\b-%\b%      Distinguish dataless files and directories with a '%' character"
# [149] "             in long (-\b-l\bl) output, and don't materialize dataless directories"
# [150] "             when listing them."
# [151] ""
# [152] "     The -\b-1\b1, -\b-C\bC, -\b-x\bx, and -\b-l\bl options all override each other; the last one"
# [153] "     specified determines the format used."
# [154] ""
# [155] "     The -\b-c\bc and -\b-u\bu options override each other; the last one specified deter-"
# [156] "     mines the file time used."
# [157] ""
# [158] "     The -\b-B\bB, -\b-b\bb, -\b-w\bw, and -\b-q\bq options all override each other; the last one"
# [159] "     specified determines the format used for non-printable characters."
# [160] ""
# [161] "     The -\b-H\bH, -\b-L\bL and -\b-P\bP options all override each other (either partially or"
# [162] "     fully); they are applied in the order specified."
# [163] ""
# [164] "     By default, l\bls\bs lists one entry per line to standard output; the excep-"
# [165] "     tions are to terminals or when the -\b-C\bC or -\b-x\bx options are specified."
# [166] ""
# [167] "     File information is displayed with one or more <blank>s separating the"
# [168] "     information associated with the -\b-i\bi, -\b-s\bs, and -\b-l\bl options."
# [169] ""
# [170] "   T\bTh\bhe\be L\bLo\bon\bng\bg F\bFo\bor\brm\bma\bat\bt"
# [171] "     If the -\b-l\bl option is given, the following information is displayed for"
# [172] "     each file: file mode, number of links, owner name, group name, number of"
# [173] "     bytes in the file, abbreviated month, day-of-month file was last modi-"
# [174] "     fied, hour file last modified, minute file last modified, and the path-"
# [175] "     name.  In addition, for each directory whose contents are displayed, the"
# [176] "     total number of 512-byte blocks used by the files in the directory is"
# [177] "     displayed on a line by itself, immediately before the information for the"
# [178] "     files in the directory.  If the file or directory has extended"
# [179] "     attributes, the permissions field printed by the -\b-l\bl option is followed by"
# [180] "     a '@' character.  Otherwise, if the file or directory has extended secu-"
# ...
# [315] "                           x\bx     default foreground or background"
# [316] ""
# [317] "                     Note that the above are standard ANSI colors.  The actual"
# [318] "                     display may differ depending on the color capabilities of"
# [319] "                     the terminal in use."
# [320] ""
# [321] "                     The order of the attributes are as follows:"
# [322] ""
# [323] "                           1.   directory"
# [324] "                           2.   symbolic link"
# [325] "                           3.   socket"
# [326] "                           4.   pipe"
# [327] "                           5.   executable"
# [328] "                           6.   block special"
# [329] "                           7.   character special"
# [330] "                           8.   executable with setuid bit set"
# [331] "                           9.   executable with setgid bit set"
# [332] "                           10.  directory writable to others, with sticky bit"
# [333] "                           11.  directory writable to others, without sticky"
# [334] "                                bit"
# [335] ""
# [336] "                     The default is \"exfxcxdxbxegedabagacad\", i.e. blue fore-"
# [337] "                     ground and default background for regular directories,"
# [338] "                     black foreground and red background for setuid executa-"
# [339] "                     bles, etc."
# [340] ""
# [341] "     LS_COLWIDTHS    If this variable is set, it is considered to be a colon-"
# [342] "                     delimited list of minimum column widths.  Unreasonable"
# [343] "                     and insufficient widths are ignored (thus zero signifies"
# [344] "                     a dynamically sized column).  Not all columns have"
# [345] "                     changeable widths.  The fields are, in order: inode,"
# [346] "                     block count, number of links, user name, group name,"
# [347] "                     flags, file size, file name."
# [348] ""
# [349] "     TERM            The CLICOLOR functionality depends on a terminal type"
# [350] "                     with color capabilities."
# [351] ""
# [352] "     TZ              The timezone to use when displaying dates.  See"
# [353] "                     environ(7) for more information."
# [354] ""
# [355] "C\bCO\bOM\bMP\bPA\bAT\bTI\bIB\bBI\bIL\bLI\bIT\bTY\bY"
# [356] "     The group field is now automatically included in the long listing for"
# [357] "     files in order to be compatible with the IEEE Std 1003.2 (``POSIX.2'')"
# [358] "     specification."
# [359] ""
# [360] "L\bLE\bEG\bGA\bAC\bCY\bY D\bDE\bES\bSC\bCR\bRI\bIP\bPT\bTI\bIO\bON\bN"
# [361] "     In legacy mode, the -\b-f\bf option does not turn on the -\b-a\ba option and the -\b-g\bg,"
# [362] "     -\b-n\bn, and -\b-o\bo options do not turn on the -\b-l\bl option."
# [363] ""
# [364] "     Also, the -\b-o\bo option causes the file flags to be included in a long (-l)"
# [365] "     output; there is no -\b-O\bO option."
# [366] ""
# [367] "     When -\b-H\bH is specified (and not overridden by -\b-L\bL or -\b-P\bP) and a file argument"
# [368] "     is a symlink that resolves to a non-directory file, the output will"
# [369] "     reflect the nature of the link, rather than that of the file.  In legacy"
# [370] "     operation, the output will describe the file."
# [371] ""
# [372] "     For more information about legacy mode, see compat(5)."
# [373] ""
# [374] "S\bSE\bEE\bE A\bAL\bLS\bSO\bO"
# [375] "     chflags(1), chmod(1), sort(1), xterm(1), compat(5), termcap(5),"
# [376] "     symlink(7), sticky(8)"
# [377] ""
# [378] "S\bST\bTA\bAN\bND\bDA\bAR\bRD\bDS\bS"
# [379] "     The l\bls\bs utility conforms to IEEE Std 1003.1-2001 (``POSIX.1'')."
# [380] ""
# [381] "H\bHI\bIS\bST\bTO\bOR\bRY\bY"
# [382] "     An l\bls\bs command appeared in Version 1 AT&T UNIX."
# [383] ""
# [384] "B\bBU\bUG\bGS\bS"
# [385] "     To maintain backward compatibility, the relationships between the many"
# [386] "     options are quite complex."
# [387] ""
# [388] "BSD                              May 19, 2002                              BSD"

# %%
# 3
system('touch data/new_folder/test.txt
rm data/new_folder/test.txt')

# %%
# 4 
system('sort data/art/artists.txt > data/new_folder/artists_sorted.txt
uniq -c data/new_folder/artists_sorted.txt', intern=TRUE)
# Out:
#   [1] "   1 AACHEN, Hans von\t(1552-1615)\tMannerism\tGerman painter"
#   [2] "   1 AAGAARD, Carl Frederik\t(1833-1895)\tRealism\tDanish painter (Copenhagen)"
#   [3] "   1 ABADIA, Juan de la\t(active 1470-1490)\tEarly Renaissance\tSpanish painter (Huesca)"
#   [4] "   1 ABAQUESNE, Masséot\t(c 1500-1564)\tHigh Renaissance\tFrench potter"
#   [5] "   1 ABBATE, Niccolò dell'\t(1509-1571)\tMannerism\tItalian painter (Bologna)"
#   [6] "   1 ABBATI, Giuseppe\t(1836-1868)\tRealism\tItalian painter"
#   [7] "   1 ABBATINI, Guido Ubaldo\t(c. 1602-1656)\tBaroque\tItalian painter (Rome)"
#   [8] "   1 ABBONDI, Antonio di Pietro (see SCARPAGNINO)\t(c. 1465-1549)\tHigh Renaissance\tItalian architect (Venice)"
#   [9] "   1 ABEELE, Pieter van\t(1608-1684)\tBaroque\tDutch sculptor (Amsterdam)"
#  [10] "   1 ABILDGAARD, Nicolai\t(1743-1809)\tRomanticism\tDanish painter"
#  [11] "   1 ABONDIO, Antonio\t(1538-1591)\tMannerism\tItalian sculptor (Vienna)"
#  [12] "   1 ACERO Y AREBO, Vicente\t(c. 1677-1739)\tBaroque\tSpanish architect"
#  [13] "   1 ACHENBACH, Oswald\t(1827-1905)\tRealism\tGerman painter (Dusseldorf)"
#  [14] "   1 ADAM, Albrecht\t(1786-1862)\tRomanticism\tGerman painter (Munich)"
#  [15] "   1 ADAM, Lambert-Sigisbert\t(1700-1759)\tBaroque\tFrench sculptor (Nancy)"
#  [16] "   1 ADAM, Nicolas-Sébastien\t(1705-1778)\tBaroque\tFrench sculptor (Nancy)"
#  [17] "   1 ADAM, Robert\t(1728-1792)\tBaroque\tScottish architect (London)"
#  [18] "   1 ADAM-SALOMON, Antoine-Samuel\t(1818-1881)\tRealism\tFrench sculptor (Paris)"
#  [19] "   1 ADELCRANTZ, Carl Fredrik\t(1716-1796)\tNeoclassicism\tSwedish architect"
#  [20] "   1 ADEMOLLO, Luigi\t(1764-1849)\tNeoclassicism\tItalian painter (Florence)"
#  [21] "   1 ADLER, Salomon\t(1630-1709)\tBaroque\tGerman painter (Milan)"
#  [22] "   1 ADOLFZOON, Christoph (see ADOLPHI, Christoffel)\t(c. 1631-1680)\tBaroque\tDutch sculptor (Amsterdam)"
#  [23] "   1 ADOLPHI, Christoffel\t(c. 1631-1680)\tBaroque\tDutch sculptor (Amsterdam)"
#  [24] "   1 ADRIAEN VAN UTRECHT (see UTRECHT, Adriaen van)\t(1599-1652)\tBaroque\tFlemish painter"
#  [25] "   1 ADRIAENSSEN, Alexander\t(1587-1661)\tBaroque\tFlemish painter (Antwerp)"
#  [26] "   1 ADRIANO FIORENTINO\t(ca. 1455-1499)\tEarly Renaissance\tItalian sculptor (Florence)"
#  [27] "   1 AELST, Willem van\t(1627-c. 1683)\tBaroque\tDutch painter (Delft)"
#  [28] "   1 AENVANCK, Theodoor\t(1633-1690)\tBaroque\tFlemish painter (Antwerp)"
#  [29] "   1 AERT VAN ORT\t(active 1490-1536)\tNorthern Renaissance\tFlemish glass painter"
#  [30] "   1 AERTSEN, Pieter\t(1508-1575)\tNorthern Renaissance\tNetherlandish painter (Amsterdam)"
#  [31] "   1 AGASSE, Jacques-Laurent\t(1767-1849)\tNeoclassicism\tSwiss painter (London)"
#  [32] "   1 AGNOLO DA SIENA (see AGNOLO DI VENTURA)\t(active 1311-1349)\tMedieval\tItalian sculptor (Siena)"
#  [33] "   1 AGNOLO DI POLO\t(c. 1470-after 1498)\tEarly Renaissance\tItalian sculptor (Florence)"
#  [34] "   1 AGNOLO DI VENTURA\t(active 1311-1349)\tMedieval\tItalian sculptor (Siena)"
#  [35] "   1 AGOSTINO DI DUCCIO\t(1418-1481)\tEarly Renaissance\tItalian sculptor (Rimini)"
#  [36] "   1 AGOSTINO DI GIOVANNI\t(active 1310-1347)\tMedieval\tItalian sculptor (Siena)"
#  [37] "   1 AGOSTINO VENEZIANO (see MUSI, Agostino dei)\t(c. 1490-c. 1536)\tHigh Renaissance\tItalian graphic artist"
#  [38] "   1 AGRATE, Gian Francesco Ferrari d'\t(1489-c. 1563)\tHigh Renaissance\tItalian sculptor (Parma)"
#  [39] "   1 AGUADO LÓPEZ, Antonio\t(1764-1831)\tNeoclassicism\tSpanish architect (Madrid)"
#  [40] "   1 AIVAZOVSKY, Ivan Konstantinovich\t(1817-1900)\tRealism\tRussian painter"
#  [41] "   1 AKEN, Joseph van\t(c. 1699-1749)\tRococo\tFlemish painter (London)"
#  [42] "   1 AKOTANTOS, Angelos\t(?-c. 1457)\tMedieval\tGreek painter (Crete)"
#  [43] "   1 ALBA, Macrino d'\t(c. 1460-c. 1528)\tEarly Renaissance\tItalian painter (Alba)"
#  [44] "   1 ALBANI, Francesco\t(1578-1660)\tBaroque\tItalian painter (Bologna)"
#  [45] "   1 ALBEREGNO, Jacobello\t(died before1397)\tMedieval\tItalian painter (Venice)"
#  [46] "   1 ALBERTI, Antonio\t(c. 1390-c. 1442)\tEarly Renaissance\tItalian painter (Urbino)"
#  [47] "   1 ALBERTI, Cherubino\t(1553-1615)\tMannerism\tItalian painter (Rome)"
#  [48] "   1 ALBERTI, Giovanni\t(1558-1601)\tMannerism\tItalian painter (Rome)"
#  [49] "   1 ALBERTI, Leon Battista\t(1404-1472)\tEarly Renaissance\tItalian architect"
#  [50] "   1 ALBERTINELLI, Mariotto\t(1474-1515)\tEarly Renaissance\tItalian painter (Florence)"
#  [51] "   1 KILIAN, Wolfgang\t(1581-1662)\tBaroque\tGerman graphic artist (Augsburg)"
#  [52] "   1 KINSOEN, François-Joseph\t(1771-1839)\tRomanticism\tFlemish painter"
#  [53] "   1 KISS, August Karl Edouard\t(1802-1865)\tRomanticism\tGerman sculptor"
#  [54] "   1 KISS, Bálint\t(1802-1868)\tRomanticism\tHungarian painter (Pest)"
#  [55] "   1 KLEINER, Salomon\t(1703-1761)\tBaroque\tGerman graphic artist"
#  [56] "   1 KLENZE, Leo von\t(1784-1864)\tRomanticism\tGerman architect"
#  [57] "   1 KLESECKER, Justus (see GLESKER, Justus)\t(c. 1615-1678)\tBaroque\tGerman sculptor (Franconia)"
#  [58] "   1 KLINGER, Max\t(1857-1920)\tRealism\tGerman painter"
#  [59] "   1 KLOCKER, Hans\t(active 1478-1500l)\tNorthern Renaissance\tAustrian sculptor (South Tyrol)"
#  [60] "   1 KLODT, Mikhail Konstantinovich\t(c. 1832-1902)\tRealism\tRussian painter (St. Petersburg)"
#  [61] "   1 KLODT, Pyotr Karlovich\t(1805-1867)\tRomanticism\tRussian sculptor (St. Petersburg)"
#  [62] "   1 KNEBEL, Franz\t(1809-1877)\tRomanticism\tSwiss painter (Rome)"
#  [63] "   1 KNELLER, Sir Godfrey\t(1646-1723)\tBaroque\tEnglish painter"
#  [64] "   1 KNIJFF, Jacob\t(1639-1681)\tBaroque\tDutch painter (London)"
#  [65] "   1 KNIJFF, Wouter\t(c. 1607-after 1693)\tBaroque\tDutch painter (Haarlem)"
#  [66] "   1 KNIP, Henriëtte\t(1821-1909)\tRealism\tDutch painter (Brussels)"
#  [67] "   1 KNIP, Henriëtte Geertruida\t(1783-1842)\tRomanticism\tDutch painter"
#  [68] "   1 KNIP, Josephus Augustus\t(1777-1847)\tRomanticism\tDutch painter"
#  [69] "   1 KNIP, Mattheus Derk\t(1785-1845)\tRomanticism\tDutch painter"
#  [70] "   1 KNIP, Nicolaas Frederik\t(1741-1808)\tRococo\tDutch painter"
#  [71] "   1 KNOBELSDORFF, Georg Wenceslaus von\t(1699-1753)\tBaroque\tGerman architect (Berlin)"
#  [72] "   1 KNOLLER, Martin\t(1725-1804)\tNeoclassicism\tAustrian painter (Italy)"
#  [73] "   1 KNYFF, Jacob (see KNIJFF, Jacob)\t(1639-1681)\tBaroque\tDutch painter (London)"
#  [74] "   1 KNYFF, Wouter (see KNIJFF, Wouter)\t(c. 1607-after 1693)\tBaroque\tDutch painter (Haarlem)"
#  [75] "   1 KNÜPFER, Nicolaus\t(c. 1603-1655)\tBaroque\tDutch painter"
#  [76] "   1 KOBELL, Franz\t(1749-1822)\tRococo\tGerman painter (Munich)"
#  [77] "   1 KOBELL, Hendrik\t(1751-1779)\tRococo\tDutch painter (Rotterdam)"
#  [78] "   1 KOBELL, Jan I\t(1755-1833)\tRococo\tDutch graphic artist (Rotterdam)"
#  [79] "   1 KOBELL, Jan II\t(1778-1814)\tNeoclassicism\tDutch painter"
#  [80] "   1 KOBELL, Wilhelm von\t(1766-1853)\tRomanticism\tGerman painter"
#  [81] "   1 KOBERGER, Anton\t(c. 1440-1513)\tNorthern Renaissance\tGerman graphic artist (Nuremberg)"
#  [82] "   1 KOCH, Joseph Anton\t(1768-1839)\tRomanticism\tAustrian painter"
#  [83] "   1 KOEBERGER, Wenzel (see COBERGHER, Wenceslas)\t(c. 1560-1634)\tBaroque\tFlemish architect"
#  [84] "   1 KOEDIJCK, Isaack\t(c. 1617-c. 1668)\tBaroque\tDutch painter (Amsterdam)"
#  [85] "   1 KOEKKOEK, Barend Cornelis\t(1803-1862)\tRomanticism\tDutch painter"
#  [86] "   1 KOERBECKE, Johann\t(c. 1420-1490)\tNorthern Renaissance\tGerman painter (Münster)"
#  [87] "   1 KOETS, Roelof\t(c. 1592-1655)\tBaroque\tDutch painter (Haarlem)"
#  [88] "   1 KOKORINOV, Alexander Filippovich\t(1726-1772)\tBaroque\tRussian architect (St. Petersburg)"
#  [89] "   1 KOLBE, Carl Wilhelm\t(1759-1835)\tNeoclassicism\tGerman painter"
#  [90] "   1 KOLLONITSCH, Christian\t(1730-1802)\tRococo\tAustrian painter (Vienna)"
#  [91] "   1 KOLUNIĆ, Martin (see ROTA, Martino)\t(c. 1520-1583)\tMannerism\tOther painter (Vienna)"
#  [92] "   1 KOMPE, Jan ten (see COMPE, Jan ten)\t(1713-1761)\tBaroque\tDutch painter (Amsterdam)"
#  [93] "   1 KONINCK, Daniël de\t(1668-after 1720)\tBaroque\tDutch painter (London)"
#  [94] "   1 KONINCK, David de (see CONINCK, David de)\t(c. 1644-c. 1701)\tBaroque\tFlemish painter"
#  [95] "   1 KONINCK, Philips\t(1619-1688)\tBaroque\tDutch painter (Amsterdam)"
#  [96] "   1 KONINCK, Salomon\t(1609-1656)\tBaroque\tDutch painter (Amsterdam)"
#  [97] "   1 KONRAD von Soest\t(active 1394-1422)\tNorthern Renaissance\tGerman painter (Westphalie)"
#  [98] "   1 KOPISCH, August\t(1799-1853)\tRomanticism\tGerman painter (Berlin)"
#  [99] "   1 KÖNIG, Johann\t(1586-1642)\tBaroque\tGerman painter (Augsburg)"
# [100] "   1 KŘBKE, Christen\t(1810-1848)\tRomanticism\tDanish painter"
# [101] "   1 TACCA, Ferdinando\t(1619-c. 1688)\tBaroque\tItalian sculptor (Florence)"
# [102] "   1 TACCA, Pietro\t(1577-1640)\tBaroque\tItalian sculptor (Florence)"
# [103] "   1 TACCONE, Paolo (see PAOLO ROMANO)\t(c. 1415-c. 1470)\tEarly Renaissance\tItalian sculptor (Rome)"
# [104] "   1 TADDEO DI BARTOLO\t(1362/63-1422)\tMedieval\tItalian painter (Siena)"
# [105] "   1 TADDEO DI FERRARA (see CRIVELLI, Taddeo)\t(active 1451-c. 1479)\tEarly Renaissance\tItalian illuminator (Ferrara)"
# [106] "   1 TADOLINI, Scipione\t(1822-1892)\tRealism\tItalian sculptor (Rome)"
# [107] "   1 TALENTI, Francesco\t(c. 1300-after 1369)\tMedieval\tItalian architect (Florence)"
# [108] "   1 TALENTI, Simone\t(c. 1330-after 1383)\tMedieval\tItalian architect (Florence)"
# [109] "   1 TALPA, Bartolo\t(active c. 1495)\tEarly Renaissance\tItalian sculptor (Mantua)"
# [110] "   1 TAMAGNI, Vincenzo\t(1492-1530)\tHigh Renaissance\tItalian painter (San Gimignano)"
# [111] "   1 TAMAGNINO, Antonio (see PORTA, Antonio della)\t(active 1489–1519)\tEarly Renaissance\tItalian sculptor"
# [112] "   1 TAMM, Franz Werner von\t(1658-1724)\tBaroque\tGerman painter"
# [113] "   1 TANZIO DA VARALLO\t(c. 1580-c. 1632)\tBaroque\tItalian painter"
# [114] "   1 TARAVAL, Guillaume-Thomas-Raphaël\t(1701-1750)\tBaroque\tFrench painter (Stockholm)"
# [115] "   1 TARAVAL, Hugues\t(1729-1785)\tRococo\tFrench painter (Paris)"
# [116] "   1 TARAVAL, Louis-Gustave\t(1738-1794)\tNeoclassicism\tFrench graphic artist"
# [117] "   1 TARBELL, Edmund Charles\t(1862-1938)\tImpressionism\tAmerican painter"
# [118] "   1 TARCHIANI, Filippo\t(1576-1645)\tBaroque\tItalian painter (Florence)"
# [119] "   1 TARDIEU, Nicolas-Henry\t(1674-1749)\tBaroque\tFrench graphic artist (Paris)"
# [120] "   1 TARGONE, Cesare\t(active 1575-1590)\tMannerism\tItalian goldsmith"
# [121] "   1 TARSIA, Antonio\t(c. 1662-1739)\tBaroque\tAustrian sculptor (Venice)"
# [122] "   1 TARUFFI, Emilio\t(1633-1696)\tBaroque\tItalian painter (Bologna)"
# [123] "   1 TASSAERT, Jean-Pierre-Antoine\t(1727-1788)\tRococo\tFlemish sculptor"
# [124] "   1 TASSAERT, Octave\t(1800-1874)\tRomanticism\tFrench painter"
# [125] "   1 TASSEL, Jean\t(1608-1667)\tBaroque\tFrench painter (Langres)"
# [126] "   1 TASSI, Agostino\t(1578-1644)\tBaroque\tItalian painter (Rome)"
# [127] "   1 TAUNAY, Nicolas Antoine\t(1755-1830)\tRococo\tFrench painter"
# [128] "   1 TEDESCO, Carlo (see SFERINI, Carlo Leopoldo)\t(1652-1698)\tBaroque\tItalian painter (Verona)"
# [129] "   1 TEDESCO, Giovanni Paolo (see SCHOR, Johann Paul)\t(1615-1674)\tBaroque\tItalian painter (Rome)"
# [130] "   1 TEERLINC, Levina\tc. 1515-1576)\tMannerism\tFlemish miniaturist (London)"
# [131] "   1 TELEPY, Károly\t(1828-1906)\tRomanticism\tHungarian painter"
# [132] "   1 TEMANZA, Tommaso\t(1705-1789)\tRococo\tItalian architect (Venice)"
# [133] "   1 TEMPEL, Abraham van den\t(1622/23-1672)\tBaroque\tDutch painter (Amsterdam)"
# [134] "   1 TEMPESTA, Antonio\t(1555-1630)\tBaroque\tItalian painter (Florence)"
# [135] "   1 TEMPESTA, Pietro (see MULIER, Pieter the Younger)\t(1637-1701)\tBaroque\tDutch painter (Italy)"
# [136] "   1 TENERANI, Pietro\t(1789-1869)\tNeoclassicism\tItalian sculptor"
# [137] "   1 TENGNAGEL, Jan\t(1584-1635)\tBaroque\tDutch painter (Amsterdam)"
# [138] "   1 TENIERS, Abraham\t(1629-1670)\tBaroque\tFlemish painter (Antwerp)"
# [139] "   1 TENIERS, David the Elder\t(1582-1649)\tBaroque\tFlemish painter (Antwerp)"
# [140] "   1 TENIERS, David the Younger\t(1610-1690)\tBaroque\tFlemish painter (Antwerp)"
# [141] "   1 TERBORCH, Gerard\t(1617-1681)\tBaroque\tDutch painter (Deventer)"
# [142] "   1 TERBRUGGHEN, Hendrick\t(1588-1629)\tBaroque\tDutch painter (Utrecht)"
# [143] "   1 TERILLI, Francesco\t(active 1610-1630)\tBaroque\tItalian sculptor (Feltre)"
# [144] "   1 TERRENI, Giuseppe Maria\t(1739-1811)\tNeoclassicism\tItalian painter (Livorno)"
# [145] "   1 TERZIO, Francesco\t(c. 1523-1591)\tMannerism\tItalian painter (Vienna)"
# [146] "   1 TESSIN, Nicodemus the Elder\t(1615-1681)\tBaroque\tSwedish architect (Stockholm)"
# [147] "   1 TESSIN, Nicodemus the Younger\t(1654-1728)\tBaroque\tSwedish architect (Stockholm)"
# [148] "   1 TESTA, Pietro\t(1611-1650)\tBaroque\tItalian painter (Rome)"
# [149] "   1 TESTELIN, Henri\t(1616-1695)\tBaroque\tFrench painter"
# [150] "   1 TETRODE, Willem Danielsz van\t(c. 1525-c. 1587)\tMannerism\tNetherlandish sculptor"

# %%
# 5

#print_names.sh

## !/usr/bin/env bash
## Filename: print_names.sh

#echo "Please type in your name:"
#read new_name

#echo "Alice"
#echo "Bob"
#echo "Cathy"
#echo $new_name

# %%
# 6
